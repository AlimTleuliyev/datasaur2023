# %%
epochs = range(10)
training_loss = [0.15510514326279565, 0.12313504684573914,
                 0.11661793400143862, 0.09829688379636073,
                 0.07600958504695066, 0.05668249788720218,
                 0.04040192709718973, 0.020153626748206265,
                 0.010833800994876174, 0.006461540274265607]
val_loss = [0.15700501592999155, 0.26127411107617343,
            0.19709784698418595, 0.19178692990151996,
            0.15191036585549061, 0.1613114681094885,
            0.20077486647741435, 0.19850642044754999,
            0.25126850656864586, 0.2798521214360583]
val_f1_score = [0.9018553032870213, 0.9149755972257899,
                0.8886332309495643, 0.9106959778115927,
                0.9191697191697191, 0.9154723842405794,
                0.9232827644332069, 0.9306079664570232,
                0.9199987389792037, 0.9195897630892402]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(8, 6))

plt.plot(epochs, training_loss, c='blue', label='Training Loss')
plt.plot(epochs, val_loss, c='orange', label='Validation Loss')
plt.title('Loss values during training')
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('submission2_results.csv')
df.head()
# Out:
#                      epoch               train/loss    metrics/accuracy_top1  \
# 0                        1                  0.08276                  0.92424
# 1                        2                  0.02954                  0.93788
# 2                        3                  0.02514                  0.93636
# 3                        4                  0.02385                  0.94545
# 4                        5                  0.02164                  0.94394
#
#      metrics/accuracy_top5                 val/loss                   lr/pg0  \
# 0                        1                  0.18685                 0.000034
# 1                        1                  0.18560                 0.000067
# 2                        1                  0.18692                 0.000100
# 3                        1                  0.17943                 0.000100
# 4                        1                  0.18108                 0.000100
#
# ...

# %%
len(df)
# Out:
# 22

# %%
train_loss = df.iloc[:, 1]
val_loss = df.iloc[:, 4]
val_acc = df.iloc[:, 2]

# %%
plt.figure(figsize=(8, 6))

epochs = range(22)
plt.plot(epochs, train_loss, c='blue', label='Training Loss')
plt.plot(epochs, val_loss, c='orange', label='Validation Loss')
plt.title('Loss values during training')
plt.legend()
plt.show()

# %%
df = pd.read_csv('submission4_results.csv')
df.head()
# Out:
#                      epoch               train/loss    metrics/accuracy_top1  \
# 0                        1                  0.23668                  0.91843
# 1                        2                  0.06690                  0.92447
# 2                        3                  0.04833                  0.92447
# 3                        4                  0.03774                  0.93051
# 4                        5                  0.02943                  0.93656
#
#      metrics/accuracy_top5                 val/loss                   lr/pg0  \
# 0                        1                  0.35103                 0.000034
# 1                        1                  0.33391                 0.000067
# 2                        1                  0.33205                 0.000100
# 3                        1                  0.32594                 0.000100
# 4                        1                  0.32914                 0.000100
#
# ...

# %%
train_loss = df.iloc[:, 1]
val_loss = df.iloc[:, 4]
val_acc = df.iloc[:, 2]

# %%
plt.figure(figsize=(8, 6))

epochs = range(len(df))
plt.plot(epochs, train_loss, c='blue', label='Training Loss')
plt.plot(epochs, val_loss, c='orange', label='Validation Loss')
plt.title('Loss values during training')
plt.legend()
plt.savefig('yolov8m.png')

# %%
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.legend()
plt.
